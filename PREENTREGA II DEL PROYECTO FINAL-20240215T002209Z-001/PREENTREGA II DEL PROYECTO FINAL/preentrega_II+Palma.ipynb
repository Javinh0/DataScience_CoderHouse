# %% [markdown]
# # Data_StoryTelling
#
# 1.   Elemento de la lista
#
# > Bloc con sangría
#
#
# 2.   Elemento de la lista
#
#
# --------------------------------------------------------------------------------
# ### Dataset seleccionado: Informe desarrollo sostenible 2023

# %% [markdown]
# ## **Descripción del Dataset:** <br/>
# <br/>
#  ### _Contexto Comercial:_
# El Informe revisa el progreso realizado cada año en los Objetivos de Desarrollo Sostenible desde su adopción por los 193 Estados miembros de las Naciones Unidas en 2015. A mitad del camino hacia 2030, el Informe sobre Desarrollo Sostenible 2023 hace un balance de los avances realizados y analiza las prioridades para restaurar y acelerar el progreso de los ODS. Publicada en vísperas de la Cumbre de París de 2023 para un Nuevo Pacto Financiero Global, la edición de este año se centra específicamente en la necesidad de aumentar la financiación para el desarrollo y reformar la arquitectura financiera global para apoyar los ODS.
#
#  ### _Resumen del informe:_
# El conjunto de datos del Informe sobre Desarrollo Sostenible 2023 comprende datos completos relacionados con la sostenibilidad y el progreso hacia los Objetivos de Desarrollo Sostenible (ODS) para numerosos países. Cada entrada en el conjunto de datos presenta información sobre los puntajes de sostenibilidad, la clasificación regional y el desempeño de un país en los ODS individuales. Este conjunto de datos proporciona información valiosa sobre los esfuerzos globales de sostenibilidad y permite una evaluación matizada del progreso de los países en el logro del desarrollo sostenible.

# %% [markdown]
# ## Contexto Analítico

# %% [markdown]
# ### Descripción de Columnas
#
#
#
# | Nombre de columna | Descripción Columna |
# | --- | --- |
# | country_code |  Un identificador único que enlaza con el conjunto de datos principal. |
# | country | El nombre del país. |
# | year |  El año de la entrada de datos. |
# | sdg_index_score |  La puntuación general del índice ODS (Objetivos de Desarrollo Sostenible) del país. |
# | goal_1_score |	La puntuación del Objetivo 1: Sin pobreza |
# | goal_2_score |	El puntaje del Objetivo 2: Hambre Cero. |
# | goal_3_score |	La puntuación del Objetivo 3: Buena salud y bienestar. |
# | goal_4_score |	La puntuación del Objetivo 4: Educación de calidad. |
# | goal_5_score |	La puntuación del Objetivo 5: Igualdad de género. |
# | goal_6_score |	La puntuación del Objetivo 6: Agua limpia y saneamiento. |
# | goal_7_score |	El puntaje del Objetivo 7: Energía limpia y asequible. |
# | goal_8_score |	La puntuación del Objetivo 8: Trabajo decente y crecimiento económico. |
# | goal_9_score |	La puntuación del Objetivo 9: Industria, Innovación e Infraestructura. |
# | goal_10_score |	La puntuación del Objetivo 10: Reducción de las desigualdades. |
# | goal_11_score |	La puntuación del Objetivo 11: Ciudades y comunidades sostenibles. |
# | goal_12_score |	La puntuación del Objetivo 12: Producción y consumo responsables. |
# | goal_13_score |	La puntuación del Objetivo 13: Acción por el clima. |
# | goal_14_score |	La puntuación del Objetivo 14: Vida bajo el agua. |
# | goal_15_score |	El puntaje del Objetivo 15: Vida en la Tierra. |
# | goal_16_score |   El puntaje del Objetivo 16: Paz, justicia e instituciones sólidas. |
# | goal_17_score |	La puntuación del Objetivo 17: Asociaciones para los Objetivos. |

# %% [markdown]
# ### Descripción de Variables
# </br>
# Durante el analisis a realizar en este dataset se consideraran las siguientes variables a calcular para cada uno de los puntajes informados en cada columna enfocados unicamente en a resultados a nivel general de los paises que conforman los Estados miembros de las Naciones Unidas, por lo cual no se segmentará por pais, si no que cada una de estas variables se agruparan en resultados anuales para el analisis de resultados cada año.
#
# Ademas a futuro se espera realizar una evaluaciones por medio de series de tiempo, del desarrollo de los puntajes en base a los años y paises evaluados
# </br>
# </br>
#
#  | Variable | Descripción | Posibles Estudios |
#  | --- | --- | --- |
#  | sdg_index_score | Puntuación general del Índice ODS | - Análisis de tendencias en la puntuación ODS a lo largo de los años.<br>- Comparación de la puntuación ODS entre diferentes regiones del mundo. |
# | goal_1_score | Puntuación del Objetivo 1: Sin pobreza | - Estudio de políticas de reducción de la pobreza y su impacto en la puntuación.<br>- Evaluación de la relación entre la pobreza y otros ODS. |
# | goal_4_score | Puntuación del Objetivo 4: Educación de calidad | - Análisis de la inversión en educación y su influencia en la puntuación.<br>- Estudio de la calidad educativa y su relación con otros ODS. |
# | goal_8_score | Puntuación del Objetivo 8: Trabajo decente y crecimiento económico | - Evaluación de políticas de empleo y crecimiento económico en relación con la puntuación.<br>- Análisis de la equidad en el mercado laboral. |
# | goal_13_score | Puntuación del Objetivo 13: Acción por el clima | - Estudio de las emisiones de gases de efecto invernadero y su impacto en la puntuación.<br>- Evaluación de políticas de mitigación del cambio climático y su efectividad. |
# | goal_17_score | Puntuación del Objetivo 17: Asociaciones para los Objetivos | - Análisis de la colaboración internacional en la consecución de los ODS.<br>- Evaluación de inversiones extranjeras y su relación con la puntuación. |
# | goal_2_score | Puntuación del Objetivo 2: Hambre Cero | - Estudio de la seguridad alimentaria y su influencia en la puntuación ODS.<br>- Evaluación de la producción y distribución de alimentos. |
# | goal_3_score | Puntuación del Objetivo 3: Buena salud y bienestar | - Análisis de la atención médica y el acceso a servicios de salud en relación con la puntuación.<br>- Estudio de la esperanza de vida y la mortalidad infantil. |
# | goal_6_score | Puntuación del Objetivo 6: Agua limpia y saneamiento | - Evaluación de la calidad del agua y el acceso a servicios de saneamiento en relación con la puntuación.<br>- Análisis de la gestión sostenible del agua. |
# | goal_9_score | Puntuación del Objetivo 9: Industria, Innovación e Infraestructura | - Estudio de la inversión en infraestructura y su impacto en la puntuación.<br>- Evaluación de la innovación y la adopción de tecnología. |
# | goal_10_score | Puntuación del Objetivo 10: Reducción de las desigualdades | - Análisis de la distribución de ingresos y la igualdad de oportunidades en relación con la puntuación.<br>- Estudio de las políticas de inclusión social. |
# | goal_11_score | Puntuación del Objetivo 11: Ciudades y comunidades sostenibles | - Evaluación de la planificación urbana y su influencia en la puntuación ODS.<br>- Análisis de la sostenibilidad de las áreas urbanas. |
# | goal_12_score | Puntuación del Objetivo 12: Producción y consumo responsables | - Estudio de los patrones de consumo y producción sostenible en relación con la puntuación.<br>- Evaluación de la gestión de residuos y la eficiencia en el uso de recursos. |
# | goal_15_score | Puntuación del Objetivo 15: Vida en la Tierra | - Análisis de la conservación de la biodiversidad y su impacto en la puntuación.<br>- Evaluación de políticas de gestión de recursos naturales. |
# | goal_16_score | Puntuación del Objetivo 16: Paz, justicia e instituciones sólidas | - Evaluación de la gobernanza, el estado de derecho y la justicia en relación con la puntuación.<br>- Análisis de la seguridad y el respeto de los derechos humanos. |

# %% [markdown]
# ### Importación de librerías y lectura del Dataframe

# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from numpy import nan
from numpy import isnan

# %%
from google.colab import files
import pandas as pd


uploaded = files.upload()

# Lee el archivo CSV
df_DSI = pd.read_csv('sdg_index_2000-2022.csv')

# Muestra las primeras filas del DataFrame
df_DSI.head()
# Out:
#      <input type="file" id="files-c2147ab7-ac35-4436-8154-54a1ee502f16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2147ab7-ac35-4436-8154-54a1ee502f16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Se renombras columnas
df_DSI= df_DSI.rename(columns={
                        "sdg_index_score":"SDG.SCORE",
                        "goal_1_score":"GOAL_1",
                        "goal_2_score":"GOAL_2",
                        "goal_3_score":"GOAL_3",
                        "goal_4_score":"GOAL_4",
                        "goal_5_score":"GOAL_5",
                        "goal_6_score":"GOAL_6",
                        "goal_7_score":"GOAL_7",
                        "goal_8_score":"GOAL_8",
                        "goal_9_score":"GOAL_9",
                        "goal_10_score":"GOAL_10",
                        "goal_11_score":"GOAL_11",
                        "goal_12_score":"GOAL_12",
                        "goal_13_score":"GOAL_13",
                        "goal_14_score":"GOAL_14",
                        "goal_15_score":"GOAL_15",
                        "goal_16_score":"GOAL_16",
                        "goal_17_score":"GOAL_17"
                       })
df_DSI.head()
# Out:
#   country_code      country  year  SDG.SCORE  GOAL_1  GOAL_2  GOAL_3  GOAL_4  \
# 0          AFG  Afghanistan  2000       36.0    28.8    27.3    19.2     1.6
# 1          AFG  Afghanistan  2001       36.3    28.8    30.6    19.4     1.6
# 2          AFG  Afghanistan  2002       36.3    28.8    30.7    19.7     1.6
# 3          AFG  Afghanistan  2003       36.7    28.8    32.5    19.9     1.6
# 4          AFG  Afghanistan  2004       37.1    28.8    32.1    21.1     1.6
#
#    GOAL_5  GOAL_6  ...  GOAL_8  GOAL_9  GOAL_10  GOAL_11  GOAL_12  GOAL_13  \
# 0    20.8    32.4  ...    38.5     5.2      0.0     25.8     94.7     99.4
# 1    20.8    32.4  ...    38.5     5.2      0.0     25.8     94.5     99.4
# 2    20.8    32.7  ...    38.4     5.2      0.0     26.1     94.1     99.4
# 3    20.8    33.0  ...    38.4     5.2      0.0     26.5     94.4     99.4
# 4    20.8    33.3  ...    38.5     5.2      0.0     26.8     94.8     99.4
#
#    GOAL_14  GOAL_15  GOAL_16  GOAL_17
# ...

# %% [markdown]
# ### Presentación de Hipotesis

# %% [markdown]
# **Hipótesis 1** - Desarrollo económico y trabajo decente: </br> ¿Existe una correlación entre el crecimiento económico (GOAL_8) y la puntuación del GOAL_1 (Sin pobreza)?</br>  ¿Los países con un crecimiento económico más sólido también han reducido significativamente la pobreza? </br> </br>

# %%
df_DSI.set_index('year', inplace=True)
df_DSI.head()
# Out:
#      country_code      country  SDG.SCORE  GOAL_1  GOAL_2  GOAL_3  GOAL_4  \
# year
# 2000          AFG  Afghanistan       36.0    28.8    27.3    19.2     1.6
# 2001          AFG  Afghanistan       36.3    28.8    30.6    19.4     1.6
# 2002          AFG  Afghanistan       36.3    28.8    30.7    19.7     1.6
# 2003          AFG  Afghanistan       36.7    28.8    32.5    19.9     1.6
# 2004          AFG  Afghanistan       37.1    28.8    32.1    21.1     1.6
#
#       GOAL_5  GOAL_6  GOAL_7  GOAL_8  GOAL_9  GOAL_10  GOAL_11  GOAL_12  \
# year
# 2000    20.8    32.4    21.0    38.5     5.2      0.0     25.8     94.7
# 2001    20.8    32.4    22.3    38.5     5.2      0.0     25.8     94.5
# 2002    20.8    32.7    21.5    38.4     5.2      0.0     26.1     94.1
# 2003    20.8    33.0    24.5    38.4     5.2      0.0     26.5     94.4
# 2004    20.8    33.3    28.0    38.5     5.2      0.0     26.8     94.8
#
#       GOAL_13  GOAL_14  GOAL_15  GOAL_16  GOAL_17
# year
# ...

# %% [markdown]
# #### Análisis Hipotesis 1:

# %%
# Se Visulaizará unicamente las columnas a evaluar (Goal_8 y Goal_ 1) pero en df diferentes
df_CE = df_DSI[["country","GOAL_8"]] #Var Independiente
df_SP = df_DSI[["country","GOAL_1"]] #Var dependiente
df_SP_CE = df_DSI[["country","GOAL_1","GOAL_8"]]
df_CE.head()
# Out:
#           country  GOAL_8
# year
# 2000  Afghanistan    38.5
# 2001  Afghanistan    38.5
# 2002  Afghanistan    38.4
# 2003  Afghanistan    38.4
# 2004  Afghanistan    38.5

# %%
    df_SP.head()
# Out:
#           country  GOAL_1
# year
# 2000  Afghanistan    28.8
# 2001  Afghanistan    28.8
# 2002  Afghanistan    28.8
# 2003  Afghanistan    28.8
# 2004  Afghanistan    28.8

# %%
df_SP_CE.head()
# Out:
#           country  GOAL_1  GOAL_8
# year
# 2000  Afghanistan    28.8    38.5
# 2001  Afghanistan    28.8    38.5
# 2002  Afghanistan    28.8    38.4
# 2003  Afghanistan    28.8    38.4
# 2004  Afghanistan    28.8    38.5

# %% [markdown]
# **Control de duplicados** (Data Wrangling)

# %%
# Se cuentan los valores nulos en cada columna df_SP_CE
nulos_por_columna = df_SP_CE.isnull().sum()

# se cuentan los  valores duplicados en el DataFrame
duplicados = df_SP_CE.duplicated().sum()

# Se muestra el número de valores nulos y de duplicados por columna
print("Total de valores duplicados en el DataFrame:", duplicados)
print("Valores nulos por columna:", nulos_por_columna)
# Out:
# Total de valores duplicados en el DataFrame: 785
# Valores nulos por columna: country    0
# GOAL_1     0
# GOAL_8     0
# dtype: int64

# %%
# Buscaremos las filas duplicadas con el fin de determinar su incidencia en nuestro futuro modelo
duplicados = df_SP_CE[df_SP_CE.duplicated()]

# Mostrar las filas duplicadas
print("Filas duplicadas:")
print(duplicados)
# Out:
# Filas duplicadas:
#           country  GOAL_1  GOAL_8
# year
# 2001  Afghanistan    28.8    38.5
# 2003  Afghanistan    28.8    38.4
# 2004  Afghanistan    28.8    38.5
# 2005  Afghanistan    28.8    38.4
# 2006  Afghanistan    28.8    38.5
# ...           ...     ...     ...
# 2010       Zambia     6.7    56.4
# 2005     Zimbabwe    31.3    61.1
# 2007     Zimbabwe    31.3    60.9
# 2009     Zimbabwe    31.3    60.8
# 2010     Zimbabwe    31.3    60.7
#
# [785 rows x 3 columns]

# %% [markdown]
# En este caso dado a que los datos duplicados son relevantes para nuestor modelo, no eliminarán, en el caso de que los duplcados estuvieran presentes en el mismo año (mismo pais) si se hubiera trabajado con los duplicados.

# %% [markdown]
# ## Análisis exploratorio de datos (EDA)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Se Configura el estilo de Seaborn
sns.set(style="whitegrid")

# Se Grafica 'GOAL_1' y 'GOAL_8' en función del tiempo (año) con leyendas
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_SP_CE, x=df_SP_CE.index, y='GOAL_1', marker='o', label='GOAL_1')
sns.lineplot(data=df_SP_CE, x=df_SP_CE.index, y='GOAL_8', marker='s', label='GOAL_8')
plt.title('Comportamiento de GOAL_8: desarrollo economico y la pobreza desde 2000 - 2022')
plt.xlabel('')
plt.ylabel('')

#Se Agrega una leyenda
plt.legend(title='Objetivo')
plt.grid(True)
plt.show()

# %% [markdown]
# **¿Existe una correlación entre el crecimiento económico (GOAL_8) y la puntuación del GOAL_1 (Sin pobreza)?** </br>¿Los países con un crecimiento económico más sólido también han reducido significativamente la pobreza?</br></br>
#
# Evaluando este primer análisis, tomando los datos de manera general, durante los primeros 10 años no se logra percibir alguna correlación, pero ya despues de del año 2010 se lograría observar que la correlación entre ambas variables comienza ser más significativa. Por ende la hipotesis tiende a cumplirse desde esas fechas

# %%
# Se filtra el DataFrame para incluir datos desde el año 2010 en adelante
df_filtered = df_SP_CE[df_SP_CE.index >= 2010]

# Se calcula la correlación entre las variables GOAL_8 y GOAL_1
correlation = df_filtered['GOAL_8'].corr(df_filtered['GOAL_1'])

print(f"Correlación entre GOAL_8 y GOAL_1 desde 2010 en adelante: {correlation}")
# Out:
# Correlación entre GOAL_8 y GOAL_1 desde 2010 en adelante: 0.4474396903963433

# %% [markdown]
# # Ahora si se considera el coef de correlación, este presenta una correlación positiva, pero mínima

# %%
# Se ordena el DataFrame por "GOAL_8" en orden descendente (mayor a menor)
Top_df_SP_CE = df_SP_CE.sort_values(by='GOAL_8', ascending=False)

# Se resetea el índice para convertir 'year' en una columna nuevamente
Top_df_SP_CE = Top_df_SP_CE.reset_index()

# Se elimina duplicados de "year" manteniendo la primera fila (la de mayor GOAL_8)
Top_df_SP_CE = Top_df_SP_CE.drop_duplicates(subset='year', keep='first')

# Se muestra el DataFrame resultante
print(Top_df_SP_CE)
# Out:
#     year country  GOAL_1  GOAL_8
# 0   2019    Cuba     0.0    93.6
# 1   2020    Cuba     0.0    93.4
# 2   2022    Cuba     0.0    93.4
# 3   2021    Cuba     0.0    93.3
# 4   2018    Cuba     0.0    93.1
# 5   2017    Cuba     0.0    93.1
# 6   2009    Cuba     0.0    93.1
# 7   2008    Cuba     0.0    93.1
# 8   2007    Cuba     0.0    93.0
# 9   2004    Cuba     0.0    93.0
# 10  2006    Cuba     0.0    92.9
# 11  2005    Cuba     0.0    92.9
# 12  2016    Cuba     0.0    92.8
# 13  2003    Cuba     0.0    92.5
# 14  2015    Cuba     0.0    92.4
# 15  2010    Cuba     0.0    92.3
# 16  2014    Cuba     0.0    92.1
# 17  2002    Cuba     0.0    91.6
# 18  2011    Cuba     0.0    91.6
# 19  2013    Cuba     0.0    91.5
# 20  2012    Cuba     0.0    91.4
# 21  2001    Cuba     0.0    90.8
# 22  2000    Cuba     0.0    89.5

# %%
#Se Filtra el DataFrame para obtener solo los datos de Cuba, ya que es el top en todos los años en el puntaje de desarrollo ecónomico
cuba_data = Top_df_SP_CE[Top_df_SP_CE['country'] == 'Cuba']


sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.lineplot(data=cuba_data, x='year', y='GOAL_1', marker='o', label='GOAL_1', color='blue')
sns.lineplot(data=cuba_data, x='year', y='GOAL_8', marker='s', label='GOAL_8', color='orange')

plt.title('Desarrollo de Cuba sin pobreza y crecimiento económico en Cuba a lo largo del tiempo')
plt.xlabel('')
plt.ylabel('')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **¿Existe una correlación entre el crecimiento económico (GOAL_8) y la puntuación del GOAL_1 (Sin pobreza)?** </br>¿Los países con un crecimiento económico más sólido también han reducido significativamente la pobreza?</br>
# En base a este primer análisis,se procede a analisar el top 1 de los paises con mayor puntaje en desarrollo economico por cada año, pero no se cumple la hipotesis planteada en este caso, ya que si bien se ha punteado cada año a cuba con mayor puntaje, la disminución de la pobreza es 0 o muy minima su evolución, por ende no se podría suponer que existe una clara correlación.</br>
#
#
# </br>
# A continuación se procede a demostrar a travez de box plots, cuanta segmentación se logra visualizar por causa de Cuba

# %%
# Creamos un nuevo df para poder graficar esto

# Primero, clonamos el DataFrame original
Top_df_SP_CE = df_SP_CE.copy()

# Cambiamos el nombre de la columna de índice a "temp_year"
Top_df_SP_CE['temp_year'] = Top_df_SP_CE.index

# Luego, ordenamos el DataFrame por "temp_year" y "GOAL_8" en orden descendente (mayor a menor)
Top_df_SP_CE = Top_df_SP_CE.sort_values(by=['temp_year', 'GOAL_8'], ascending=[True, False])


# Usamos groupby para obtener los dos primeros países por año

Top_2_countries_per_year = Top_df_SP_CE.groupby('temp_year').head(2)


# Eliminamos la columna temporal "temp_year"
Top_2_countries_per_year = Top_2_countries_per_year.drop(columns=['temp_year'])

# Muestra el DataFrame resultante
print(Top_2_countries_per_year)
# Out:
#           country  GOAL_1  GOAL_8
# year
# 2000         Cuba     0.0    89.5
# 2000       Sweden    98.6    87.8
# 2001         Cuba     0.0    90.8
# 2001       Sweden    98.6    88.3
# 2002         Cuba     0.0    91.6
# 2002       Sweden    98.6    88.2
# 2003         Cuba     0.0    92.5
# 2003       Sweden    98.6    87.8
# 2004         Cuba     0.0    93.0
# 2004  New Zealand     0.0    87.4
# 2005         Cuba     0.0    92.9
# 2005  New Zealand     0.0    87.5
# 2006         Cuba     0.0    92.9
# 2006      Denmark    99.3    87.9
# 2007         Cuba     0.0    93.0
# 2007      Denmark    99.3    87.8
# 2008         Cuba     0.0    93.1
# 2008      Denmark    99.3    87.7
# 2009         Cuba     0.0    93.1
# 2009  Korea, Rep.    98.9    87.0
# 2010         Cuba     0.0    92.3
# 2010  Korea, Rep.    98.9    87.0
# 2011         Cuba     0.0    91.6
# 2011  Korea, Rep.    99.0    87.2
# 2012         Cuba     0.0    91.4
# 2012  Korea, Rep.    99.0    87.2
# ...

# %%
# Se Configura el estilo de Seaborn
sns.set(style="whitegrid")

# Se crea una figura y ejes para los subgráficos
fig, axes = plt.subplots(1, 2, figsize=(30, 6))

# Se Grafica una visualización de caja de bigotes para GOAL_8 en el nuevo DataFrame
sns.boxplot(data=Top_2_countries_per_year, x='year', y='GOAL_8', color='lightgreen', ax=axes[0])
axes[0].set_title('Box plot con df sin segmentar de Goal_8:crecimiento económico')
axes[0].set_xlabel('')
axes[0].set_ylabel(' ')

# Se Grafica una visualización de caja de bigotes para GOAL_1 en el nuevo DataFrame
sns.boxplot(data=Top_2_countries_per_year, x='year', y='GOAL_1', color='skyblue', ax=axes[1])
axes[1].set_title('Box plot con df sin segmentar de Goal_1:sin pobreza')
axes[1].set_xlabel('')
axes[1].set_ylabel(' ')

# Ajustar el espacio entre los gráficos
plt.subplots_adjust(wspace=5)

# Se ajusta el diseño para evitar solapamiento
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ***Dado a que el resustado esta demaciado sesgado a favor de cuba en relacion al puntaje obtenido por desarrollo economico vs disminución de la disminución de la pobreza, entonces se procederá a segmentar por los demas paises***

# %%
# Se elimina a cuba para mejorar la segmentación y resultados del analsiis y  Usamos groupby para obtener los dos primeros países por año
Top_2_countries_per_year2 = Top_df_SP_CE.query('country != "Cuba" and GOAL_1 != 0').groupby('temp_year').head(2)


# Eliminamos la columna temporal "temp_year"
Top_2_countries_per_year2 = Top_2_countries_per_year2.drop(columns=['temp_year'])

# Muestra el DataFrame resultante
print(Top_2_countries_per_year2)
# Out:
#           country  GOAL_1  GOAL_8
# year
# 2000       Sweden    98.6    87.8
# 2000      Denmark    99.3    87.6
# 2001       Sweden    98.6    88.3
# 2001      Denmark    99.3    87.6
# 2002       Sweden    98.6    88.2
# 2002      Denmark    99.3    87.7
# 2003       Sweden    98.6    87.8
# 2003      Denmark    99.3    87.1
# 2004      Denmark    99.3    87.1
# 2004  Korea, Rep.    98.9    87.0
# 2005      Denmark    99.3    87.3
# 2005  Korea, Rep.    98.9    87.0
# 2006      Denmark    99.3    87.9
# 2006  Korea, Rep.    98.9    87.1
# 2007      Denmark    99.3    87.8
# 2007  Korea, Rep.    98.9    87.2
# 2008      Denmark    99.3    87.7
# 2008  Korea, Rep.    98.9    87.2
# 2009  Korea, Rep.    98.9    87.0
# 2009      Denmark    99.3    86.5
# 2010  Korea, Rep.    98.9    87.0
# 2010      Finland    99.5    86.2
# 2011  Korea, Rep.    99.0    87.2
# 2011      Finland    99.5    86.4
# 2012  Korea, Rep.    99.0    87.2
# 2012      Finland    99.5    86.5
# ...

# %%
# Se Configura el estilo de Seaborn
sns.set(style="whitegrid")

# Se crea una figura y ejes para los subgráficos
fig, axes = plt.subplots(1, 2, figsize=(30, 6))

# Se Grafica una visualización de caja de bigotes para GOAL_8 en el nuevo DataFrame
sns.boxplot(data=Top_2_countries_per_year2, x='year', y='GOAL_8', color='lightgreen', ax=axes[0])
axes[0].set_title('Box plot con df segmentado de Goal_8:crecimiento económico')
axes[0].set_xlabel('')
axes[0].set_ylabel('')

# Se Grafica una visualización de caja de bigotes para GOAL_1 en el nuevo DataFrame
sns.boxplot(data=Top_2_countries_per_year2, x='year', y='GOAL_1', color='skyblue', ax=axes[1])
axes[1].set_title('Box plot con df segmentado de Goal_1:sin pobreza')
axes[1].set_xlabel('')
axes[1].set_ylabel(' ')

# Ajustar el espacio entre los gráficos
plt.subplots_adjust(wspace=5)

# Se ajusta el diseño para evitar solapamiento
plt.tight_layout()
plt.show()

# %% [markdown]
# ### A Continuación observaremos ambas situaciones con el fin de dimencionar el estado de nuestros datos sin eliminar los nulos y outliers provocados por cuba y como se podrá observar el data set limpio.

# %%
# Se Configura el estilo de Seaborn
sns.set(style="whitegrid")

# Se crea una figura y ejes para los subgráficos
fig, axes = plt.subplots(2, 2, figsize=(30, 9))

# Se Grafica una visualización de caja de bigotes para GOAL_8 en el DataFrame Top_2_countries_per_year
sns.boxplot(data=Top_2_countries_per_year, x='year', y='GOAL_8', color='lightgreen', ax=axes[0, 0])
axes[0, 0].set_title('Box plot con df sin segmentar de Goal_8:crecimiento económico')
axes[0, 0].set_xlabel('')
axes[0, 0].set_ylabel('')

# Se Grafica una visualización de caja de bigotes para GOAL_1 en el DataFrame Top_2_countries_per_year
sns.boxplot(data=Top_2_countries_per_year, x='year', y='GOAL_1', color='skyblue', ax=axes[0, 1])
axes[0, 1].set_title('Box plot con df sin segmentar de Goal_1:sin pobreza')
axes[0, 1].set_xlabel('')
axes[0, 1].set_ylabel('')

# Se Grafica una visualización de caja de bigotes para GOAL_8 en el DataFrame Top_2_countries_per_year2
sns.boxplot(data=Top_2_countries_per_year2, x='year', y='GOAL_8', color='lightgreen', ax=axes[1, 0])
axes[1, 0].set_title('Box plot con df segmentado de Goal_8:crecimiento económico')
axes[1, 0].set_xlabel('')
axes[1, 0].set_ylabel('')

# Se Grafica una visualización de caja de bigotes para GOAL_1 en el DataFrame Top_2_countries_per_year2
sns.boxplot(data=Top_2_countries_per_year2, x='year', y='GOAL_1', color='skyblue', ax=axes[1, 1])
axes[1, 1].set_title('Box plot con df segmentado de Goal_1:sin pobreza')
axes[1, 1].set_xlabel('')
axes[1, 1].set_ylabel('')

# Ajustar el espacio entre los gráficos
plt.subplots_adjust(wspace=1, hspace=1)

# Ajustar el diseño para evitar solapamiento
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlación de la disminución de la pobreza y el desarrollo economico

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#variables GOAL_1 y GOAL_8 del DataFrame:
data = df_SP_CE[['GOAL_1', 'GOAL_8']]

X = data[['GOAL_1']]
y = data['GOAL_8']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f"Coeficiente de determinación (R²): {r2}")
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.title('Regresión Lineal: GOAL_1 vs. GOAL_8')
plt.xlabel('GOAL_1')
plt.ylabel('GOAL_8')
plt.show()
# Out:
# Coeficiente de determinación (R²): 0.17363632131951323

# %% [markdown]
# Finalmente y para encontrar un puntaje optimo entre la correlación de la disminución de la pobreza y el desarrollo economico, los niveles de desarrollo deberían estar por sobre los 70ptos, para asi lograr una disminución optima de los niveles de pobreza en los paises. Tal cual lo demuestra el grafico de más abajo (sin considerar los valores de paises atipicos como el caso antes analisado de cuba)

# %%
# se crea una nueva columna 'color' basada en la condición GOAL_8 >= 70
df_DSI['color'] = np.where(df_DSI['GOAL_8'] >= 70, 'green', 'blue')

# Graficar la relación entre GOAL_8 y GOAL_1 con colores diferenciados
plt.figure(figsize=(10, 6))
plt.scatter(df_DSI['GOAL_8'], df_DSI['GOAL_1'], alpha=0.5, c=df_DSI['color'])
plt.xlabel('Desarrollo Económico (GOAL_8)')
plt.ylabel('Disminución de la Pobreza (GOAL_1)')
plt.title('Relación entre GOAL_8 y GOAL_1 con colores diferenciados por GOAL_8 >= 70')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ingenieria de Atributos

# %% [markdown]
# **Feature Selection**

# %% [markdown]
# Como parte del Feature selection lo primero que realizaremos será escalar variables para posteriormente a aplicar el modelo de PCA.

# %%
from sklearn.preprocessing import StandardScaler

#Se escalan las variables numericas

scaler = StandardScaler()
scaled = scaler.fit_transform(
    df_DSI[['GOAL_1',	'GOAL_2',	'GOAL_3',	'GOAL_4',	'GOAL_5',	'GOAL_6',	'GOAL_7',	'GOAL_8',	'GOAL_9',	'GOAL_10',	'GOAL_11',	'GOAL_12',	'GOAL_13',	'GOAL_14',	'GOAL_15',	'GOAL_16',	'GOAL_17']].values)

# %% [markdown]
# # **Analisis de Correlación**

# %%
#Se crea la matriz de covarianza
covariance_matrix = np.cov(scaled.T)
covariance_matrix
# Out:
# array([[ 1.0002416 ,  0.4064841 ,  0.64611524,  0.61048237,  0.39282038,
#          0.65235234,  0.61685884,  0.44123619,  0.53101453,  0.4449843 ,
#          0.56474193, -0.4264901 , -0.25500308,  0.07158065,  0.1615454 ,
#          0.47629259,  0.41160034],
#        [ 0.4064841 ,  1.0002416 ,  0.61344917,  0.58887101,  0.53065111,
#          0.62426661,  0.55429396,  0.60596156,  0.60844575,  0.15602239,
#          0.53392278, -0.43384797, -0.35074554,  0.12633745,  0.118496  ,
#          0.48242153,  0.28623274],
#        [ 0.64611524,  0.61344917,  1.0002416 ,  0.84200643,  0.61491157,
#          0.78911139,  0.86809806,  0.68990978,  0.80453579,  0.28480776,
#          0.82535607, -0.77082515, -0.61445807,  0.19576409,  0.0671885 ,
#          0.75753323,  0.48262053],
#        [ 0.61048237,  0.58887101,  0.84200643,  1.0002416 ,  0.66250562,
#          0.7174128 ,  0.80482291,  0.6307368 ,  0.67837502,  0.20140952,
# ...

# %% [markdown]
# **A continuación se identificaran el minimo de Variables que necesitamos**

# %%
sns.pairplot(df_DSI)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Ahora solo para visualizar GOAL_1 Y GOAL_8, dado que aparte de ser las variables a estudiar, al revisar los diagramas de dispersión logramos observar que mantienen una correcta correlación

sns.jointplot(x= df_DSI['GOAL_1'], y= df_DSI['GOAL_8'])

#Ademas es interesante visualizar con datos estandarizados estas variables

sns.jointplot(x = scaled[:,2], y= scaled[:,3])

# %% [markdown]
# **Descomposición de Vectores**

# %%
eigen_values, eigen_vectors = np.linalg.eig(covariance_matrix)

# %%
#visualizando Valores propios
eigen_values
# Out:
# array([9.00784052, 1.39144602, 1.12734714, 0.99107986, 0.87882744,
#        0.7449192 , 0.53757759, 0.40543714, 0.37575993, 0.32796893,
#        0.08255448, 0.09274464, 0.27181041, 0.25235442, 0.15366354,
#        0.17974573, 0.18303027])

# %%
#Visualizando Vectores propios
eigen_vectors
# Out:
# array([[-2.26298518e-01, -2.48548896e-01,  2.36003736e-01,
#         -3.21391311e-01, -2.36035731e-01,  3.85007007e-02,
#         -3.86571985e-01, -1.41760799e-01,  4.13838330e-01,
#          1.86206265e-01, -4.82888854e-02, -2.04182309e-02,
#          4.20806983e-01, -2.74172474e-01, -1.99700388e-01,
#         -2.17171202e-02,  2.91497361e-03],
#        [-2.28024726e-01,  3.99238626e-02,  1.49420573e-01,
#          7.56761858e-02,  2.50076381e-01,  5.92086811e-01,
#          2.21679386e-01, -4.87518612e-01, -1.53579179e-01,
#          3.01420072e-01,  3.11471023e-02, -1.35123223e-01,
#         -1.55275251e-01, -1.78359525e-01, -1.10011187e-01,
#         -5.44581659e-02, -1.17373565e-01],
#        [-3.12319732e-01,  1.03428032e-01,  6.07175670e-02,
#         -5.29994818e-02, -1.04545300e-01, -2.05607718e-02,
#         -9.42616558e-02, -7.36451633e-02, -4.44119439e-02,
#         -7.32426971e-02,  8.39121561e-01,  2.59349868e-01,
# ...

# %%
#Generamos lista variance_explained
variance_explained = []
for i in eigen_values:
      variance_explained.append((i/sum(eigen_values))*100)

print(variance_explained)
# Out:
# [52.97449833423128, 8.182999567664567, 6.629851986816088, 5.82847335440623, 5.168324516525832, 4.380819233789, 3.1614572761222064, 2.384348276475267, 2.2098186442631955, 1.9287629865832017, 0.48549727394232023, 0.5454248997192559, 1.5984985420699978, 1.4840792162152414, 0.9036848284470739, 1.05707245174998, 1.076388610979259]

# %% [markdown]
# ### Entrenamiento y testeo

# %% [markdown]
# **Rescaleo de Datos**

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

#preparando data
df_DSI.drop(['country_code',	'country',	'SDG.SCORE',	'GOAL_1',	'GOAL_2',	'GOAL_4',	'GOAL_5',	'GOAL_6',		'GOAL_7',	'GOAL_9',	'GOAL_10',	'GOAL_11',	'GOAL_12',	'GOAL_13',	'GOAL_14',	'GOAL_15',	'GOAL_16',	'GOAL_17'],axis=1)

# Machine Learning
X = df_DSI['GOAL_8']
y = df_DSI['GOAL_1']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### Regresión logística

# %%
# Con esto nos aseguramos de que X_train y X_test tengan al menos 2D
if X_train.ndim == 1:
    X_train = X_train.values.reshape(-1, 1)

if X_test.ndim == 1:
    X_test = X_test.values.reshape(-1, 1)

# se crea  el objeto StandardScaler
scaler = StandardScaler()

# se ajusta el escalador en los datos de entrenamiento y aplicarlo a los datos de prueba
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# se obtiene el número mínimo entre el número de muestras y características
num_components = min(X_train_scaled.shape[0], X_train_scaled.shape[1])

# se ajusta PCA a tus datos escalados de entrenamiento y transformarlos
pca = PCA(n_components=num_components)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Se ajusta un modelo de regresión lineal (puedes cambiarlo según tu necesidad)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_pca, y_train)

# Se hacen predicciones en el conjunto de prueba
y_pred = model.predict(X_test_pca)

# Calcular métricas de evaluación para un problema de regresión
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Error cuadrático medio:", mse)
print("Coeficiente de determinación (R^2):", r2)
# Out:
# Error cuadrático medio: 1035.6339695494423
# Coeficiente de determinación (R^2): 0.2155259424323107

# %%
pca.explained_variance_ratio_
# Out:
# array([1.])

# %%
df_DSI['pca_1'] = scaled[:, 0]
df_DSI['pca_2'] = scaled[:, 1]
sns.jointplot(data=df_DSI, x='pca_1', y='pca_2')
sns.jointplot(data=df_DSI, x='GOAL_1', y='GOAL_8')

# %% [markdown]
# ### Árbol de decisión

# %% [markdown]
# **Impotacion de las bibliotecas scikit-learn**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , mean_squared_error, r2_score
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Calculo de precisión , error cuadrático medio y coeficiente de determinación del arbol de decisión

# %%
from sklearn.tree import DecisionTreeRegressor

# Con esto nos aseguramos de que X_train y X_test tengan al menos 2D
if X_train.ndim == 1:
    X_train = X_train.values.reshape(-1, 1)

if X_test.ndim == 1:
    X_test = X_test.values.reshape(-1, 1)

# se crea  el objeto StandardScaler
scaler = StandardScaler()

# se ajusta el escalador en los datos de entrenamiento y aplicarlo a los datos de prueba
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# se obtiene el número mínimo entre el número de muestras y características
num_components = min(X_train_scaled.shape[0], X_train_scaled.shape[1])

# se ajusta PCA a tus datos escalados de entrenamiento y transformarlos
pca = PCA(n_components=num_components)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Se ajusta un modelo de árbol de decisiones
tree_model = DecisionTreeRegressor()
tree_model.fit(X_train_pca, y_train)

# Se hacen predicciones en el conjunto de prueba
y_pred_tree = tree_model.predict(X_test_pca)

# Calcular métricas de evaluación para un problema de regresión
mse_tree = mean_squared_error(y_test, y_pred_tree)
r2_tree = r2_score(y_test, y_pred_tree)
print("Error cuadrático medio del árbol de decisiones:", mse_tree)
print("Coeficiente de determinación (R^2) del árbol de decisiones:", r2_tree)
# Out:
# Error cuadrático medio del árbol de decisiones: 992.7725537545233
# Coeficiente de determinación (R^2) del árbol de decisiones: 0.24799269202759877

# %% [markdown]
# ### Conclusiones
#
# 1. **Desempeño del Modelo de Árbol de Decisiones:**
#    - El modelo de árbol de decisiones muestra un Error Cuadrático Medio (MSE) de 992.772553 y un Coeficiente de Determinación (R^2) de 0.24799
#   <br/> Estas métricas indican un rendimiento moderado del modelo.
#
# 2. **Análisis de Correlación entre Crecimiento Económico y Pobreza:**
#    - El análisis general sugiere una correlación más clara entre el crecimiento económico (GOAL_8) y la reducción de la pobreza (GOAL_1) a partir del año 2010.
#    - Sin embargo, al realizar un análisis específico para el país líder en desarrollo económico (Cuba), se observa que la correlación entre el crecimiento económico y la reducción de la pobreza es más compleja y no se puede generalizar, pero al conocer el contecxto economico y politico del país se podría aislar del modelo.
#
# 3. **Complejidad de la Relación entre Variables:**
#    - Los resultados indican que la relación entre el crecimiento económico y la puntuación del GOAL_1 varía según el enfoque del análisis.
#    - No se puede asumir una correlación clara entre estas variables, y la relación puede depender de factores específicos de cada país.
#
# 4. **Necesidad de Probar Nuevos Modelos:**
#    - Aunque el modelo de árbol de decisiones proporciona información útil, se sugiere explorar otros modelos para mejorar la precisión y comprensión del problema.
#
#
# 5. **Consideraciones Adicionales:**
#    - La relación entre variables puede ser no lineal, y la aplicación de técnicas más avanzadas podría capturar relaciones más sutiles.
#    - La inclusión de más características relevantes o la ingeniería de características podría mejorar la capacidad del modelo para explicar la variabilidad en los datos.
#
# En resumen, aunque el modelo actual ofrece información valiosa, se recomienda explorar y probar otros modelos más complejos para obtener una comprensión más completa y precisa de la relación entre el crecimiento económico y la reducción de la pobreza. Además, considerar la inclusión de más variables y técnicas avanzadas podría enriquecer el análisis.

# %% [markdown]
# ### Evaluando modelos ML
# Al analizar las métricas generadas para evaluar si existe una situación de overfitting (sobreajuste) o underfitting (subajuste) se obtiene que:
#
# 1. **Error Cuadrático Medio (MSE):**
#    - **Interpretación:** Un MSE más bajo indica un mejor ajuste del modelo a los datos.
#    - **Resultado Actual:** MSE de 992.772553 para el modelo de árbol de decisiones.
#
# 2. **Coeficiente de Determinación (R^2):**
#    - **Interpretación:** Un R^2 más cercano a 1 indica un mejor ajuste del modelo a los datos.
#    - **Resultado Actual:** R^2 de 0.2479 para el modelo de árbol de decisiones.
#
# **Posibles Escenarios:**
# - **Overfitting (Sobreajuste):**
#   - **Indicadores:** Diferencia significativa entre el rendimiento en el conjunto de entrenamiento y prueba.
#   - **Soluciones Posibles:** Regularización del modelo, reducción de la complejidad, uso de más datos de entrenamiento.
#
# - **Underfitting (Subajuste):**
#   - **Indicadores:** Rendimiento deficiente tanto en entrenamiento como en prueba.
#   - **Soluciones Posibles:** Aumento de la complejidad del modelo, uso de características más relevantes, recopilación de más datos.
#
# **Análisis del Resultado Actual:**
# - El modelo de árbol de decisiones parece tener un rendimiento moderado según las métricas.
# - Es importante comparar el rendimiento en el conjunto de entrenamiento y prueba.
#
# **A considerar:**
# 1. **Análisis Adicional:**
#    - Evaluar el rendimiento en el conjunto de entrenamiento y prueba por separado. Si hay una gran brecha, puede indicar overfitting.
#
# 2. **Regularización:**
#    - Considerar la aplicación de técnicas de regularización, como la poda del árbol de decisiones, para reducir la complejidad y prevenir overfitting.
#
# 3. **Validación Cruzada:**
#    - Implementar la validación cruzada para obtener evaluaciones más robustas del rendimiento del modelo.
